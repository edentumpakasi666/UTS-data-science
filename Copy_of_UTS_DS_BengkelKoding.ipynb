# %% [markdown]
# # **PREDIKSI CUACA**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Dalam project ini kita akan melakukan prediksi cuaca dengan dataset **seattle-weather**.
#
# Link **dataset**:
# https://drive.google.com/file/d/1IIyYZEQReb4VavO_piu3qQeGK6VcwGJm/view?usp=sharing

# %% [markdown]
# ## **Data Preprocessing**

# %% [markdown]
# 1. Isi _code-cell_ dibawah dengan kode untuk:
#     - **membaca dataset** _seattle-weather_
#     - **menampilkan 15** baris data teratas

# %%
import pandas as pd

# Memberikan alamat file path
file_path = '/content/drive/MyDrive/data science/seattle-weather.csv'

# Membaca dataset CSV ke dalam DataFrame
data = pd.read_csv(file_path)

# Menampilkan beberapa baris pertama dari dataset
print(data.head())
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
# Menampilkan 15 baris data teratas dari DataFrame
print(data.head(15))
# Out:
#           date  precipitation  temp_max  temp_min  wind  weather
# 0   2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1   2012-01-02           10.9      10.6       2.8   4.5     rain
# 2   2012-01-03            0.8      11.7       7.2   2.3     rain
# 3   2012-01-04           20.3      12.2       5.6   4.7     rain
# 4   2012-01-05            1.3       8.9       2.8   6.1     rain
# 5   2012-01-06            2.5       4.4       2.2   2.2     rain
# 6   2012-01-07            0.0       7.2       2.8   2.3     rain
# 7   2012-01-08            0.0      10.0       2.8   2.0      sun
# 8   2012-01-09            4.3       9.4       5.0   3.4     rain
# 9   2012-01-10            1.0       6.1       0.6   3.4     rain
# 10  2012-01-11            0.0       6.1      -1.1   5.1      sun
# 11  2012-01-12            0.0       6.1      -1.7   1.9      sun
# 12  2012-01-13            0.0       5.0      -2.8   1.3      sun
# ...

# %%
# tulis jawaban anda pada code-cell berikut

# %% [markdown]
# 2. Munculkan **informasi** dataset dan lakukan **cleaning data** yang dibutuhkan:
#     - mengecek dan menghapus **nilai kosong**
#     - menghapus (**_drop_**) kolom _"date"_
#     - mengecek dan menghapus data yang memiliki **nilai duplikat**

# %%
# Menampilkan informasi dataset
print("Informasi Dataset:")
print(data.info())

# Mengecek dan menghitung nilai kosong dalam dataset
missing_values = data.isna()
missing_counts = missing_values.sum()

# Menampilkan jumlah nilai kosong dalam setiap kolom
print("\nJumlah Nilai Kosong dalam Setiap Kolom:")
print(missing_counts)

# Menghapus baris yang mengandung nilai kosong
data_cleaned = data.dropna()

# Menampilkan informasi dataset setelah pembersihan
print("\nInformasi Dataset setelah Pembersihan:")
print(data_cleaned.info())

# Menampilkan beberapa baris pertama dataset setelah pembersihan
print("\nBeberapa Baris Pertama Dataset setelah Pembersihan:")
print(data_cleaned.head())
# Out:
# Informasi Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB
# None
#
# Jumlah Nilai Kosong dalam Setiap Kolom:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64
#
# Informasi Dataset setelah Pembersihan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
# ...

# %%
# Menghapus kolom "date" dari DataFrame
data_cleaned = data_cleaned.drop(columns=['date'])

# Menampilkan hasil setelah menghapus kolom "date"
print("DataFrame setelah menghapus kolom 'date':")
print(data_cleaned)
# Out:
# DataFrame setelah menghapus kolom 'date':
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7  drizzle
# 1              10.9      10.6       2.8   4.5     rain
# 2               0.8      11.7       7.2   2.3     rain
# 3              20.3      12.2       5.6   4.7     rain
# 4               1.3       8.9       2.8   6.1     rain
# ...             ...       ...       ...   ...      ...
# 1456            8.6       4.4       1.7   2.9     rain
# 1457            1.5       5.0       1.7   1.3     rain
# 1458            0.0       7.2       0.6   2.6      fog
# 1459            0.0       5.6      -1.0   3.4      sun
# 1460            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
# Mengecek data yang memiliki nilai duplikat
duplicates = data_cleaned[data_cleaned.duplicated()]

# Menampilkan data yang memiliki nilai duplikat
print("Data dengan nilai duplikat:")
print(duplicates)

# Menghapus data yang memiliki nilai duplikat
data_cleaned_no_duplicates = data_cleaned.drop_duplicates()

# Menampilkan hasil setelah menghapus data yang memiliki nilai duplikat
print("\nDataFrame setelah menghapus data dengan nilai duplikat:")
print(data_cleaned_no_duplicates)
# Out:
# Data dengan nilai duplikat:
#       precipitation  temp_max  temp_min  wind weather
# 188             0.0      26.7      12.8   3.8     sun
# 629             0.0      21.1      13.3   2.5     sun
# 748             0.0       9.4       0.6   2.2     sun
# 751             0.0      10.0       1.7   1.5     sun
# 863             0.0      26.7      12.8   3.8     sun
# 959             0.0      27.8      15.0   2.8     sun
# 1019            0.0      20.6      11.1   3.3     sun
# 1346            0.0      22.8      13.3   2.4     sun
#
# DataFrame setelah menghapus data dengan nilai duplikat:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7  drizzle
# 1              10.9      10.6       2.8   4.5     rain
# 2               0.8      11.7       7.2   2.3     rain
# 3              20.3      12.2       5.6   4.7     rain
# 4               1.3       8.9       2.8   6.1     rain
# ...             ...       ...       ...   ...      ...
# ...

# %%
# tulis jawaban anda pada code-cell berikut

# %%
# tulis jawaban anda pada code-cell berikut

# %%
# tulis jawaban anda pada code-cell berikut

# %%
# tulis jawaban anda pada code-cell berikut

# %% [markdown]
# ## **Visualisasi**

# %% [markdown]
# ![WhatsApp Image 2023-10-30 at 21.41.56.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 3. Diatas adalah contoh visualisasi menggunakan _diagram pie_,
#
#     buatlah **visualisasi distribusi _target-class_** seperti diatas!

# %%
import matplotlib.pyplot as plt

# Hitung jumlah setiap kategori target class
target_counts = data_cleaned['weather'].value_counts()

# Bagian dari pie chart
labels = target_counts.index
sizes = target_counts.values

# Membuat pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Memastikan lingkaran pie berbentuk lingkaran

# Menambahkan judul
plt.title('Distribusi Target Class')

# Menampilkan pie chart
plt.show()

# %% [markdown]
# 4. Anda akan melakukan **visualisasi relasi antar fitur** menggunakan _diagram scatter_.
#
#     Perbaiki kata **'fix_me'** pada _code-cell_ dibawah!

# %%
from matplotlib.lines import Line2D

target_names = data['weather'].unique()

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

# Mengganti 'snow' menjadi 2, karena 'snow' terdaftar dua kali
target = data['weather'].replace({
  'drizzle': 0,
  'rain': 1,
  'snow': 2,
  'fog': 3,
  'sun': 4
})

# Visualisasi relasi fitur temp_max dan temp_min
a_scatter = axs[0].scatter(data['temp_max'], data['temp_min'], c=target, cmap='viridis')
axs[0].set(xlabel="temp_max", ylabel="temp_min")

# Visualisasi relasi fitur precipitation dan wind
b_scatter = axs[1].scatter(data['precipitation'], data['wind'], c=target, cmap='viridis')
axs[1].set(xlabel="precipitation", ylabel="wind")

from matplotlib.lines import Line2D

# Membuat legenda kustom
legend_elements = [Line2D([0], [0], marker='o', color='w', label=target_names[i], markerfacecolor=f"C{i}", markersize=10) for i in range(len(target_names))]

axs[0].legend(handles=legend_elements, loc="upper right", title="Classes")
axs[1].legend(handles=legend_elements, loc="lower right", title="Classes")


fig.suptitle("Relasi Antar Nilai Target", fontsize=20, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 4, figsize=(20, 5))
plt.suptitle('Fitur', fontsize=25, fontweight='bold', color='navy')

# axis 1
sns.histplot(data=data, x='precipitation', ax=axes[0])

# axis 2
sns.histplot(data=data, x='wind', ax=axes[1])

# axis 3
sns.histplot(data=data, x='temp_max', ax=axes[2])

# axis 4
sns.histplot(data=data, x='temp_min', ax=axes[3])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Modelling**

# %% [markdown]
# 5. **Bagi dataset** menjadi _train-set_ dan _test-set_ dengan ketentuan sebagai berikut:
#
#     a. X = seluruh kolom fitur kecuali kolom target
#
#     b. y = kolom target
#
#     c. Bagi dengan rasio 70% _train-set_ dan 30% _test-set_

# %%
from sklearn.model_selection import train_test_split

# Pisahkan kolom target (y) dari kolom fitur (X)
X = data.drop(columns=['weather'])
y = data['weather']

# Bagi dataset menjadi train-set dan test-set (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=3)

# Output dari pemisahan dataset
print("Jumlah data dalam train-set: ", len(X_train))
print("Jumlah data dalam test-set: ", len(X_test))
# Out:
# Jumlah data dalam train-set:  1022
# Jumlah data dalam test-set:  439

# %% [markdown]
# 6. **Perbaiki kata 'fix_me'** pada _code-cell_ dibawah untuk **menampilkan visualisasi rasio _target-class_** pada _train-set_ dan _test-set_!

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 7))
target_names = data['weather'].unique()
colors1 = ['gold', 'lightcoral', 'lightsteelblue']
colors2 = ['coral', 'lightgreen', 'lightskyblue']

# Train dataset
axs[0].pie(pd.Series(y_train).value_counts(), labels=target_names, colors=colors1, autopct='%1.1f%%', startangle=90)
axs[0].set_title("Train Set", fontweight="bold")

# Test dataset
axs[1].pie(pd.Series(y_test).value_counts(), labels=target_names, colors=colors2, autopct='%1.1f%%', startangle=90)
axs[1].set_title("Test Set", fontweight="bold")

fig = fig.suptitle("Rasio Tiap Set", fontsize=20, fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# 7.  Buatlah model dengan salah satu algoritma klasifikasi lalu latih dan prediksi dataset!

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Inisialisasi model
model = RandomForestClassifier(random_state=42)

# Melatih model pada train-set
model.fit(X_train, y_train)

# Prediksi target pada test-set
y_pred = model.predict(X_test)

# Menampilkan laporan klasifikasi
classification_rep = classification_report(y_test, y_pred)
print("Laporan Klasifikasi:\n", classification_rep)

# Matriks konfusi
confusion = confusion_matrix(y_test, y_pred)
print("Matriks Konfusi:\n", confusion)
# Out:
# Laporan Klasifikasi:
#                precision    recall  f1-score   support
#
#      drizzle       0.25      0.06      0.09        18
#          fog       0.20      0.08      0.12        36
#         rain       0.95      0.92      0.93       178
#         snow       1.00      0.36      0.53        11
#          sun       0.75      0.93      0.83       196
#
#     accuracy                           0.81       439
#    macro avg       0.63      0.47      0.50       439
# weighted avg       0.77      0.81      0.78       439
#
# Matriks Konfusi:
#  [[  1   0   0   0  17]
#  [  0   3   0   0  33]
#  [  0   4 163   0  11]
#  [  0   0   7   4   0]
#  [  3   8   2   0 183]]

# %% [markdown]
# ## **Evaluasi**

# %% [markdown]
# 8. Munculkan akurasi yang dihasilkan dari model yang anda gunakan.

# %%
from sklearn.metrics import accuracy_score

# Menghitung akurasi
accuracy = accuracy_score(y_test, y_pred)
print("Akurasi Model:", accuracy)
# Out:
# Akurasi Model: 0.806378132118451

# %% [markdown]
# ## **Esai**

# %% [markdown]
# 9. Berikan kesimpulan dari project yang telah anda buat.

# %% [markdown]
# 1. Persiapan Data: Project ini dimulai dengan mengimpor dataset Seattle Weather dan melakukan beberapa langkah persiapan data. Data ini berisi informasi tentang cuaca harian di Seattle.
#
# 2. Analisis Data Exploratory (EDA): EDA dilakukan untuk memahami struktur dan fitur data saat ini. Untuk menganalisis data, visualisasi seperti histogram dan scatter plot digunakan.
#
# 3. Pembersihan Data: Untuk memastikan bahwa data dalam bentuk yang tepat untuk analisis dan pemodelan, nilai kosong dan data yang tidak sesuai diidentifikasi, dihapus, atau diisi.
#
# 4. Pembagian Data: Set data dibagi menjadi set pelatihan dan set uji, dengan rasio 70% pelatihan dan 30% test set. Data pelatihan digunakan untuk melatih model, sementara data uji digunakan untuk menguji kinerja model.
#
# 5. Membangun Model: RandomForestClassifier model klasifikasi digunakan untuk memprediksi cuaca berdasarkan fitur cuaca. Model dilatih pada data pelatihan dan kemudian digunakan untuk membuat prediksi pada set data uji.
#
# 6. Evaluasi Model: Berbagai metrik, seperti akurasi, laporan klasifikasi, dan matriks konfusi, digunakan untuk mengevaluasi kinerja model. Akurasi model adalah sekitar 80.6% , yang berarti sekitar 80.6% prediksi yang benar.
#
# 7. Kesimpulan Akhir: Berdasarkan informasi cuaca yang tersedia, model Random Forest Classifier yang digunakan pada dataset cuaca Seattle cukup baik dalam memprediksi cuaca. Meskipun demikian, masih ada ruang untuk perbaikan dan eksperimen tambahan dalam pengolahan data dan pemodelan. Kesimpulan ini didasarkan pada hasil evaluasi kinerja model dan metrik yang digunakan.

# %% [markdown]
# 10. Upload dan lampirkan link
#     - **Video** penjelasan berdurasi 10-15 menit mengenai project anda.
#     - **Repository Github** berisi file notebook (_.ipynb_) anda.

# %%
link_video = " https://youtu.be/InElbhVZVjw "
link_github = ""
